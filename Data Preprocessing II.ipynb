# %% [markdown]
# Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Image
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# Load Dataset

# %%
# %time train_data = pd.read_csv("Train.csv", delimiter=',', index_col =0)
# %time test_data = pd.read_csv("Test.csv", delimiter=',', index_col =0)
# Out:
# Wall time: 20.9 ms
# Wall time: 13 ms

# %%
train_data.sample(5)
# Out:
#             Song Name   Artist's Name  Duration of Music (seconds) Category  \
# SongID
# 24          Dark Side  Kelly Clarkson                          224    angry
# 23      Breathe Again  Sara Bareilles                          298      sad
# 75        How Could I    Marc Anthony                          270      sad
# 66        Let It Rain      Olivia Ong                          271  relaxed
# 27        Dear Father          Sum 41                          234    angry
#
#                                                    Lyrics
# SongID
# 24      there's a place that i know it's not pretty th...
# 23      Car is parked, bags are packed, but what kind ...
# 75      Oh...Ummm... It was a coldest day in December ...
# 66      Oh the sky`s grey On this workday You`re just ...
# 27      I address this letter to dear Father I know yo...

# %%
test_data.sample(5)
# Out:
#                    Song Name      Artist's Name  Duration of Music (seconds)  \
# SongID
# 47                 Shattered  trading yesterday                          295
# 18                      Sick       Adelitas Way                          191
# 96             You Know What        Craig David                          217
# 8       All The Pretty Girls               Fun.                          206
# 49                The Priest        Limp Bizkit                          299
#
#        Category                                             Lyrics
# SongID
# 47          sad  Yesterday I died, tomorrow's bleeding, Fall in...
# 18        angry  I'm so sick of me, being sick of you, And the ...
# 96          sad  I know that I said I'm feeling I'm feeling it ...
# 8         happy  All the pretty girls on a Saturday night So I ...
# 49        angry  It could be the absinth talking (I don't think...

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## 1. Data Cleaning

# %% [markdown]
# ### Detecting the Missing Value

# %%
train_data.isna()
# Out:
#         Song Name  Artist's Name  Duration of Music (seconds)  Category  \
# SongID
# 1           False          False                        False     False
# 2           False          False                        False     False
# 3           False          False                        False     False
# 4           False          False                        False     False
# 5           False          False                        False     False
# ...           ...            ...                          ...       ...
# 96          False          False                        False     False
# 97          False          False                        False     False
# 98          False          False                        False     False
# 99          False          False                        False     False
# 100         False          False                        False     False
#
#         Lyrics
# SongID
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# ...        ...
# 96       False
# 97       False
# 98       False
# 99       False
# 100      False
#
# [400 rows x 5 columns]

# %%
test_data.isna()
# Out:
#         Song Name  Artist's Name  Duration of Music (seconds)  Category  \
# SongID
# 1           False          False                        False     False
# 2           False          False                        False     False
# 3           False          False                        False     False
# 4           False          False                        False     False
# 5           False          False                        False     False
# ...           ...            ...                          ...       ...
# 97          False          False                        False     False
# 98          False          False                        False     False
# 99          False          False                        False     False
# 100         False          False                        False     False
# 101         False          False                        False     False
#
#         Lyrics
# SongID
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# ...        ...
# 97       False
# 98       False
# 99       False
# 100      False
# 101      False
#
# [378 rows x 5 columns]

# %% [markdown]
# ### Summarizing the Missing Value

# %%
train_data.isna().sum()
# Out:
# Song Name                      0
# Artist's Name                  0
# Duration of Music (seconds)    0
# Category                       0
# Lyrics                         0
# dtype: int64

# %%
test_data.isna().sum()
# Out:
# Song Name                      0
# Artist's Name                  0
# Duration of Music (seconds)    0
# Category                       0
# Lyrics                         0
# dtype: int64

# %% [markdown]
# Column does not contain Missing Values

# %% [markdown]
# ## 2. Case Folding

# %%
train_data['Lyrics'] = train_data['Lyrics'].str.lower()

# %%
train_Lyrics = train_data.iloc[:400]
print(train_Lyrics['Lyrics'])
# Out:
# SongID
# 1      another day wasted out of time i can't get out...
# 2      crawl from the wreckage one more time horrific...
# 3      don't wanna be an american idiot.  don't want ...
# 4      the more of you that i inspect the more of me ...
# 5      the prophets of god have left you solaced inde...
#                              ...
# 96     over the rainbow what a wonderful world "orion...
# 97     the sunshineâs come, the flowers dance along...
# 98     this stone that i have swallowed isn't goin do...
# 99     love is like an aero plane you jump and then y...
# 100    wise men say wise men say wise men say the bad...
# Name: Lyrics, Length: 400, dtype: object

# %%
test_data['Lyrics'] = test_data['Lyrics'].str.lower()

# %%
test_Lyrics = test_data.iloc[:400]
print(test_Lyrics['Lyrics'])
# Out:
# SongID
# 1      sometimes you just feel tired, feel weak when ...
# 2      too late for the other side caught in a change...
# 3      cast your eyes into the distance try to focus ...
# 4      look like ass, smell like shit why are you suc...
# 5      you find me offensive i find you offensive for...
#                              ...
# 97     the bluest skies don't seem so blue and the st...
# 98     you are my sunshine, my only sunshine you make...
# 99     see the pyramids along the nile watch the sunr...
# 100    see the pyramids along the nile watch the sun ...
# 101    staring at the moon so blue turning all my tho...
# Name: Lyrics, Length: 378, dtype: object

# %% [markdown]
# ## 3. Tokenization

# %%
import re
import nltk
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import RegexpTokenizer

# %%
Regtokenizer = RegexpTokenizer(train_Lyrics)
print(Regtokenizer)
# Out:
# RegexpTokenizer(pattern=                                               Song Name  \
# SongID
# 1                                          All Messed Up
# 2                                     All Nightmare Long
# 3                         American Idiot (Album Version)
# 4                                            Angry Again
# 5       Annihilation By The Hands Of God (Album Version)
# ...                                                  ...
# 96             Over The Rainbow _ What A Wonderful World
# 97                                          Over The Way
# 98                                       Paper Aeroplane
# 99                                             Parachute
# 100                   Pinocchio Story (Freestyle Live Fr
#
#                 Artist's Name  Duration of Music (seconds) Category  \
# SongID
# 1                      Sum 41                          164    angry
# 2                   Metallica                          477    angry
# 3                   Green Day                          176    angry
# 4                    Megadeth                          242    angry
# 5           Roadrunner United                          333    angry
# ...                       ...                          ...      ...
# 96      Israel Kamakawiwo'ole                          295  relaxed
# 97                     »Æ½¨Îª                          271  relaxed
# 98                KT Tunstall                          199  relaxed
# 99                Sean Lennon                          201  relaxed
# 100                Kanye West                          362  relaxed
#
#                                                    Lyrics
# SongID
# 1       another day wasted out of time i can't get out...
# 2       crawl from the wreckage one more time horrific...
# 3       don't wanna be an american idiot.  don't want ...
# 4       the more of you that i inspect the more of me ...
# 5       the prophets of god have left you solaced inde...
# ...                                                   ...
# 96      over the rainbow what a wonderful world "orion...
# 97      the sunshineâs come, the flowers dance along...
# 98      this stone that i have swallowed isn't goin do...
# 99      love is like an aero plane you jump and then y...
# 100     wise men say wise men say wise men say the bad...
#
# [400 rows x 5 columns], gaps=False, discard_empty=True, flags=<RegexFlag.UNICODE|DOTALL|MULTILINE: 56>)

# %%
Regtokenizer = RegexpTokenizer(test_Lyrics)
print(Regtokenizer)
# Out:
# RegexpTokenizer(pattern=                     Song Name           Artist's Name  \
# SongID
# 1             'Till I Collapse                  Eminem
# 2                   25 To Life                  Eminem
# 3               A Century Ends              David Gray
# 4                      A N I C                  Sum 41
# 5                     Rain Man                  Eminem
# ...                        ...                     ...
# 97                         You             chris young
# 98         You Are My Sunshine             Carly Simon
# 99            You Belong To Me             Carla Bruni
# 100           You Belong To Me              Jason Wade
# 101     You Took My Heart Away  Michael Learns To Rock
#
#         Duration of Music (seconds) Category  \
# SongID
# 1                               299    angry
# 2                               644    angry
# 3                               308    angry
# 4                                41    angry
# 5                               320    angry
# ...                             ...      ...
# 97                              164  relaxed
# 98                              156  relaxed
# 99                              185  relaxed
# 100                             165  relaxed
# 101                             274  relaxed
#
#                                                    Lyrics
# SongID
# 1       sometimes you just feel tired, feel weak when ...
# 2       too late for the other side caught in a change...
# 3       cast your eyes into the distance try to focus ...
# 4       look like ass, smell like shit why are you suc...
# 5       you find me offensive i find you offensive for...
# ...                                                   ...
# 97      the bluest skies don't seem so blue and the st...
# 98      you are my sunshine, my only sunshine you make...
# 99      see the pyramids along the nile watch the sunr...
# 100     see the pyramids along the nile watch the sun ...
# 101     staring at the moon so blue turning all my tho...
#
# [378 rows x 5 columns], gaps=False, discard_empty=True, flags=<RegexFlag.UNICODE|DOTALL|MULTILINE: 56>)

# %%
from nltk.tokenize import word_tokenize

# %%
import string 
import re
#remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

train_data['Lyrics'] = train_data['Lyrics'].apply(remove_number)

#remove punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

train_data['Lyrics'] = train_data['Lyrics'].apply(remove_punctuation)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

train_data['Lyrics'] = train_data['Lyrics'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

train_data['Lyrics'] = train_data['Lyrics'].apply(remove_whitespace_multiple)

# remove single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

train_data['Lyrics'] = train_data['Lyrics'].apply(remove_singl_char)

# NLTK word tokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

train_data['Lyrics_tokens']= train_data['Lyrics'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n') 
print(train_data['Lyrics_tokens'])
print('\n\n\n')
# Out:
# Tokenizing Result :
#
# SongID
# 1      [another, day, wasted, out, of, time, cant, ge...
# 2      [crawl, from, the, wreckage, one, more, time, ...
# 3      [dont, wan, na, be, an, american, idiot, dont,...
# 4      [the, more, of, you, that, inspect, the, more,...
# 5      [the, prophets, of, god, have, left, you, sola...
#                              ...
# 96     [over, the, rainbow, what, wonderful, world, o...
# 97     [the, sunshineâ, come, the, flowers, dance, ...
# 98     [this, stone, that, have, swallowed, isnt, goi...
# 99     [love, is, like, an, aero, plane, you, jump, a...
# 100    [wise, men, say, wise, men, say, wise, men, sa...
# Name: Lyrics_tokens, Length: 400, dtype: object

# %%
train_data.sample(5)
# Out:
#                         Song Name        Artist's Name  \
# SongID
# 27                         Cancer  My Chemical Romance
# 5       Captains And Cruise Ships             Owl City
# 38                       Honestly        Jo De La Rosa
# 90                  It's All Okay          Julia Stone
# 47                           Gold             Owl City
#
#         Duration of Music (seconds) Category  \
# SongID
# 27                              144      sad
# 5                               246    happy
# 38                              208  relaxed
# 90                              234      sad
# 47                              240    happy
#
#                                                    Lyrics  \
# SongID
# 27      if you could get me  drink of water cause my l...
# 5        am stuck in la through the week and cant get ...
# 38      ever since you came into my life ever since th...
# 90      the story is different now the records are pla...
# 47      skech it up and take  bow therere something th...
#
#                                             Lyrics_tokens
# SongID
# 27      [if, you, could, get, me, drink, of, water, ca...
# 5       [am, stuck, in, la, through, the, week, and, c...
# 38      [ever, since, you, came, into, my, life, ever,...
# 90      [the, story, is, different, now, the, records,...
# 47      [skech, it, up, and, take, bow, therere, somet...

# %%
import string 
import re
#remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

test_data['Lyrics'] = test_data['Lyrics'].apply(remove_number)

#remove punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

test_data['Lyrics'] = test_data['Lyrics'].apply(remove_punctuation)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

test_data['Lyrics'] = test_data['Lyrics'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

test_data['Lyrics'] = test_data['Lyrics'].apply(remove_whitespace_multiple)

# remove single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

test_data['Lyrics'] = test_data['Lyrics'].apply(remove_singl_char)

# NLTK word tokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

test_data['Lyrics_tokens']= test_data['Lyrics'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n') 
print(test_data['Lyrics_tokens'])
print('\n\n\n')
# Out:
# Tokenizing Result :
#
# SongID
# 1      [sometimes, you, just, feel, tired, feel, weak...
# 2      [too, late, for, the, other, side, caught, in,...
# 3      [cast, your, eyes, into, the, distance, try, t...
# 4      [look, like, ass, smell, like, shit, why, are,...
# 5      [you, find, me, offensive, find, you, offensiv...
#                              ...
# 97     [the, bluest, skies, dont, seem, so, blue, and...
# 98     [you, are, my, sunshine, my, only, sunshine, y...
# 99     [see, the, pyramids, along, the, nile, watch, ...
# 100    [see, the, pyramids, along, the, nile, watch, ...
# 101    [staring, at, the, moon, so, blue, turning, al...
# Name: Lyrics_tokens, Length: 378, dtype: object

# %%
test_data.sample(5)
# Out:
#                                  Song Name               Artist's Name  \
# SongID
# 29                             But For Now                Jamie Cullum
# 91                         Whiskey Lullaby  Alison Krauss,Brad Paisley
# 19                     Skinny Little Bitch                        Hole
# 48      The Life And Death Of Mr. Badmouth                   Pj Harvey
# 55                                  So Far               Chris Garneau
#
#         Duration of Music (seconds) Category  \
# SongID
# 29                              241  relaxed
# 91                              260      sad
# 19                              194    angry
# 48                              290    angry
# 55                              265  relaxed
#
#                                                    Lyrics  \
# SongID
# 29      sure  know you like to have me talk about my f...
# 91      she put him out like the burnin end of  midnig...
# 19      in your desperation to disappear and you would...
# 48      baby you got  bad bad mouth everything is pois...
# 55      like the touch of my mothers hand on my head i...
#
#                                             Lyrics_tokens
# SongID
# 29      [sure, know, you, like, to, have, me, talk, ab...
# 91      [she, put, him, out, like, the, burnin, end, o...
# 19      [in, your, desperation, to, disappear, and, yo...
# 48      [baby, you, got, bad, bad, mouth, everything, ...
# 55      [like, the, touch, of, my, mothers, hand, on, ...

# %% [markdown]
# ## 4. Stopwords Removal

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords = nltk.corpus.stopwords.words('english')

# %%
print (stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
list_stopwords = set(nltk.corpus.stopwords.words('english'))

def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]
train_data['Lyrics_tokens_SW'] = train_data['Lyrics_tokens'].apply(stopwords_removal) 
print(train_data['Lyrics_tokens_SW'])
# Out:
# SongID
# 1      [another, day, wasted, time, cant, get, altere...
# 2      [crawl, wreckage, one, time, horrific, memory,...
# 3      [dont, wan, na, american, idiot, dont, want, n...
# 4      [inspect, see, reflect, try, read, lips, mask,...
# 5      [prophets, god, left, solaced, indeed, zombie,...
#                              ...
# 96     [rainbow, wonderful, world, orion, somewhere, ...
# 97     [sunshineâ, come, flowers, dance, along, riv...
# 98     [stone, swallowed, isnt, goin, well, road, fol...
# 99     [love, like, aero, plane, jump, pray, lucky, o...
# 100    [wise, men, say, wise, men, say, wise, men, sa...
# Name: Lyrics_tokens_SW, Length: 400, dtype: object

# %%
train_data.sample(5)
# Out:
#                  Song Name       Artist's Name  Duration of Music (seconds)  \
# SongID
# 95                Lovefool       The Cardigans                          197
# 96      Loving You Tonight        Andrew Allen                          181
# 38                Honestly       Jo De La Rosa                          208
# 30         End Of The Line  Traveling Wilburys                          207
# 47        Gunpowder & Lead     Miranda Lambert                          514
#
#        Category                                             Lyrics  \
# SongID
# 95        happy  dear  fear werre facing  problem you love me n...
# 96        happy  lost in the day in  way its the same  the one ...
# 38      relaxed  ever since you came into my life ever since th...
# 30        happy  ï»¿well its all right riding around in the bre...
# 47        angry  im goin home gonna load my shotgun wait by the...
#
#                                             Lyrics_tokens  \
# SongID
# 95      [dear, fear, werre, facing, problem, you, love...
# 96      [lost, in, the, day, in, way, its, the, same, ...
# 38      [ever, since, you, came, into, my, life, ever,...
# 30      [ï, », ¿well, its, all, right, riding, around,...
# 47      [im, goin, home, gon, na, load, my, shotgun, w...
#
#                                          Lyrics_tokens_SW
# SongID
# 95      [dear, fear, werre, facing, problem, love, lon...
# 96      [lost, day, way, one, wish, could, say, thats,...
# 38      [ever, since, came, life, ever, since, time, s...
# 30      [ï, », ¿well, right, riding, around, breeze, w...
# 47      [im, goin, home, gon, na, load, shotgun, wait,...

# %%
list_stopwords = set(nltk.corpus.stopwords.words('english'))

def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]
test_data['Lyrics_tokens_SW'] = test_data['Lyrics_tokens'].apply(stopwords_removal) 
print(test_data['Lyrics_tokens_SW'])
# Out:
# SongID
# 1      [sometimes, feel, tired, feel, weak, feel, wea...
# 2      [late, side, caught, change, life, late, side,...
# 3      [cast, eyes, distance, try, focus, find, spiri...
# 4      [look, like, ass, smell, like, shit, dick, wal...
# 5      [find, offensive, find, offensive, finding, of...
#                              ...
# 97     [bluest, skies, dont, seem, blue, stars, seem,...
# 98     [sunshine, sunshine, make, happy, skies, gray,...
# 99     [see, pyramids, along, nile, watch, sunrise, t...
# 100    [see, pyramids, along, nile, watch, sun, rise,...
# 101    [staring, moon, blue, turning, thoughts, witho...
# Name: Lyrics_tokens_SW, Length: 378, dtype: object

# %%
test_data.sample(5)
# Out:
#                       Song Name         Artist's Name  \
# SongID
# 22       Never Gonna Love Again              Lykke Li
# 53             Saturday'S Child           The Monkees
# 66      Something Good Can Work  Two Door Cinema Club
# 25                Boogie Street         Leonard Cohen
# 88         Whataya Want From Me          Adam Lambert
#
#         Duration of Music (seconds) Category  \
# SongID
# 22                              240      sad
# 53                              161    happy
# 66                              193    happy
# 25                              362  relaxed
# 88                              230      sad
#
#                                                    Lyrics  \
# SongID
# 22      baby can you hear the rain fall on me never go...
# 53      farewell my child its time to leave this all b...
# 66      theres  spanner in the works you know you gott...
# 25       crown of light  darkened one  never thought w...
# 88      hey slow it down what do you want from me what...
#
#                                             Lyrics_tokens  \
# SongID
# 22      [baby, can, you, hear, the, rain, fall, on, me...
# 53      [farewell, my, child, its, time, to, leave, th...
# 66      [theres, spanner, in, the, works, you, know, y...
# 25      [crown, of, light, darkened, one, never, thoug...
# 88      [hey, slow, it, down, what, do, you, want, fro...
#
#                                          Lyrics_tokens_SW
# SongID
# 22      [baby, hear, rain, fall, never, gon, na, love,...
# 53      [farewell, child, time, leave, behind, exchang...
# 66      [theres, spanner, works, know, got, ta, step, ...
# 25      [crown, light, darkened, one, never, thought, ...
# 88      [hey, slow, want, want, yeah, im, afraid, want...
