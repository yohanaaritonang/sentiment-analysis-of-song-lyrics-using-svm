# %% [markdown]
# Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Image
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# Load Dataset

# %%
# %time train_data = pd.read_csv("D:/Folder Mata Kuliah/Semester 7/PBA/Proyek/Dataset/Train.csv", delimiter=',', index_col =0)
# %time test_data = pd.read_csv("D:/Folder Mata Kuliah/Semester 7/PBA/Proyek/Dataset/Test.csv", delimiter=',', index_col =0)
# Out:
# Wall time: 18 ms
# Wall time: 17 ms

# %%
train_data.sample(5)
# Out:
#                        Song Name   Artist's Name  Duration of Music (seconds)  \
# SongID
# 16                    Be Alright   Justin Bieber                          191
# 4                         Bubbly  Colbie Caillat                          222
# 87               Littlest Things      Lily Allen                          186
# 38      Do I Have To Cry For You     Nick Carter                          218
# 12                 Angel Of Mine          Monica                          251
#
#        Category                                             Lyrics
# SongID
# 16          sad  Across the ocean across the sea Startin' to fo...
# 4         happy  will you come in... I've been awake for a whil...
# 87        happy  Sometimes I find myself sittin' back and remin...
# 38          sad  Don't wanna close the door Don't wanna give up...
# 12          sad  When I first saw you I already knew There was ...

# %%
test_data.sample(5)
# Out:
#                       Song Name         Artist's Name  \
# SongID
# 99             You Belong To Me           Carla Bruni
# 37                        Polly             Keren Ann
# 97                    You Stole             Brand New
# 66      Something Good Can Work  Two Door Cinema Club
# 12                    Manhattan        Sara Bareilles
#
#         Duration of Music (seconds) Category  \
# SongID
# 99                              185  relaxed
# 37                              198      sad
# 97                              360      sad
# 66                              193    happy
# 12                              279      sad
#
#                                                    Lyrics
# SongID
# 99      See the pyramids along the Nile Watch the sunr...
# 37      I will know as long as I live that it was all ...
# 97      Last night they said the fire had spread And w...
# 66      There''s a spanner in the works, you know, You...
# ...

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## 1. Data Cleaning

# %% [markdown]
# ### Detecting the Missing Value

# %%
train_data.isna()
# Out:
#         Song Name  Artist's Name  Duration of Music (seconds)  Category  \
# SongID
# 1           False          False                        False     False
# 2           False          False                        False     False
# 3           False          False                        False     False
# 4           False          False                        False     False
# 5           False          False                        False     False
# ...           ...            ...                          ...       ...
# 96          False          False                        False     False
# 97          False          False                        False     False
# 98          False          False                        False     False
# 99          False          False                        False     False
# 100         False          False                        False     False
#
#         Lyrics
# SongID
# 1        False
# 2        False
# 3        False
# 4        False
# ...

# %%
test_data.isna()
# Out:
#         Song Name  Artist's Name  Duration of Music (seconds)  Category  \
# SongID
# 1           False          False                        False     False
# 2           False          False                        False     False
# 3           False          False                        False     False
# 4           False          False                        False     False
# 5           False          False                        False     False
# ...           ...            ...                          ...       ...
# 97          False          False                        False     False
# 98          False          False                        False     False
# 99          False          False                        False     False
# 100         False          False                        False     False
# 101         False          False                        False     False
#
#         Lyrics
# SongID
# 1        False
# 2        False
# 3        False
# 4        False
# ...

# %% [markdown]
# ### Summarizing the Missing Value

# %%
train_data.isna().sum()
# Out:
# Song Name                      0
# Artist's Name                  0
# Duration of Music (seconds)    0
# Category                       0
# Lyrics                         0
# dtype: int64

# %%
test_data.isna().sum()
# Out:
# Song Name                      0
# Artist's Name                  0
# Duration of Music (seconds)    0
# Category                       0
# Lyrics                         0
# dtype: int64

# %% [markdown]
# Column does not contain Missing Values

# %% [markdown]
# ## 2. Case Folding

# %%
train_data['Lyrics'] = train_data['Lyrics'].str.lower()
test_data['Lyrics'] = test_data['Lyrics'].str.lower()

# %%
print(train_data)
# Out:
#                                                Song Name  \
# SongID
# 1                                          All Messed Up
# 2                                     All Nightmare Long
# 3                         American Idiot (Album Version)
# 4                                            Angry Again
# 5       Annihilation By The Hands Of God (Album Version)
# ...                                                  ...
# 96             Over The Rainbow _ What A Wonderful World
# 97                                          Over The Way
# 98                                       Paper Aeroplane
# 99                                             Parachute
# 100                   Pinocchio Story (Freestyle Live Fr
#
#                 Artist's Name  Duration of Music (seconds) Category  \
# SongID
# 1                      Sum 41                          164    angry
# 2                   Metallica                          477    angry
# ...

# %%
print(test_data)
# Out:
#                      Song Name           Artist's Name  \
# SongID
# 1             'Till I Collapse                  Eminem
# 2                   25 To Life                  Eminem
# 3               A Century Ends              David Gray
# 4                      A N I C                  Sum 41
# 5                     Rain Man                  Eminem
# ...                        ...                     ...
# 97                         You             chris young
# 98         You Are My Sunshine             Carly Simon
# 99            You Belong To Me             Carla Bruni
# 100           You Belong To Me              Jason Wade
# 101     You Took My Heart Away  Michael Learns To Rock
#
#         Duration of Music (seconds) Category  \
# SongID
# 1                               299    angry
# 2                               644    angry
# 3                               308    angry
# 4                                41    angry
# 5                               320    angry
# ...
